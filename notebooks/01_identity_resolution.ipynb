# %% [markdown]
# # Identity Resolution
# Measure lookup and manual intervention

# %%
import csv
rows=list(csv.DictReader(open('../data/02_identity_resolution/identity_search_events.csv',encoding='utf-8-sig')))
print(len(rows))
