# %% [markdown]
# # Financial Model
# Compare interventions

# %%
import csv
rows=list(csv.DictReader(open('../data/07_financial_model/intervention_scenarios.csv',encoding='utf-8-sig')))
print(max(rows,key=lambda r:float(r['year1_net_benefit_bdt'])))
