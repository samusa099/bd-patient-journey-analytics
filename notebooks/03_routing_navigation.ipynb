# %% [markdown]
# # Routing & Navigation
# Evaluate queue-aware routing

# %%
import csv
rows=list(csv.DictReader(open('../data/04_routing/routing_decisions.csv',encoding='utf-8-sig')))
print(len(rows))
