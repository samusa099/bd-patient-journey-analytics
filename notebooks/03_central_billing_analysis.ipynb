# %% [markdown]
# # Central Billing Analysis

# %%
import csv
from pathlib import Path
with open(Path('../data/raw_synthetic/billing_ledger.csv'),encoding='utf-8-sig') as f: rows=list(csv.DictReader(f))
print(len(rows))
