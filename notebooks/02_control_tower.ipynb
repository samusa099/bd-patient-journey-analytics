# %% [markdown]
# # Control Tower
# Analyze accept/override behavior

# %%
import csv
rows=list(csv.DictReader(open('../data/03_workflow/front_desk_control_tower.csv',encoding='utf-8-sig')))
print(sum(r['front_desk_action']=='Override' for r in rows)/len(rows))
