# %% [markdown]
# # HR Operations
# Analyze staffing demand

# %%
import csv,statistics
rows=list(csv.DictReader(open('../data/06_hr_operations/staff_shifts.csv',encoding='utf-8-sig')))
print(statistics.mean(float(r['patients_per_active_staff']) for r in rows))
