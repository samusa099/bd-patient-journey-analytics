# %% [markdown]
# # Predictive Operations
# Queue forecast baseline

# %%
import csv
rows=list(csv.DictReader(open('../data/08_predictive_operations/predictive_queue_features.csv',encoding='utf-8-sig')))
print(len(rows))
