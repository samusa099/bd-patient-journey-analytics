# %% [markdown]
# # Central Billing
# Compare payment touchpoints

# %%
import csv,statistics
rows=list(csv.DictReader(open('../data/09_analysis_ready/journey_summary.csv',encoding='utf-8-sig')))
print(statistics.mean(int(r['baseline_payment_touchpoints']) for r in rows))
