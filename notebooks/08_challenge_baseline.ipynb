# %% [markdown]
# # Challenge Baseline
# Starter learner analysis

# %%
import csv
rows=list(csv.DictReader(open('../data/09_analysis_ready/journey_kpis.csv',encoding='utf-8-sig')))
print(len(rows))
