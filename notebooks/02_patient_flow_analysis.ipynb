# %% [markdown]
# # Patient Flow Analysis

# %%
import csv
from pathlib import Path
with open(Path('../data/processed/journey_summary.csv'),encoding='utf-8-sig') as f: rows=list(csv.DictReader(f))
print(len(rows))
